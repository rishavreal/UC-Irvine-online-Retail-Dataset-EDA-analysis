# %%
# !pip install openpyxl

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# !wget https://archive.ics.uci.edu/static/public/352/online+retail.zip
# Out:
# --2025-05-08 00:44:28--  https://archive.ics.uci.edu/static/public/352/online+retail.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘online+retail.zip’
#
# online+retail.zip       [     <=>            ]  22.62M  25.7MB/s    in 0.9s
#
# 2025-05-08 00:44:30 (25.7 MB/s) - ‘online+retail.zip’ saved [23715478]

# %%
# !unzip online+retail.zip
# Out:
# Archive:  online+retail.zip
#  extracting: Online Retail.xlsx

# %%
df1= pd.read_excel('Online Retail.xlsx',dtype={'InvoiceNo':'string','StockCode':'string','Description':'string','Country':'string'})
df1.head(3)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                 WHITE METAL LANTERN         6
# 2    536365    84406B      CREAM CUPID HEARTS COAT HANGER         8
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom

# %%
df1.shape
# Out:
# (541909, 8)

# %%
df1[df1.Description.isnull()]
# Out:
#        InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 622       536414     22139        <NA>        56 2010-12-01 11:52:00
# 1970      536545     21134        <NA>         1 2010-12-01 14:32:00
# 1971      536546     22145        <NA>         1 2010-12-01 14:33:00
# 1972      536547     37509        <NA>         1 2010-12-01 14:33:00
# 1987      536549    85226A        <NA>         1 2010-12-01 14:34:00
# ...          ...       ...         ...       ...                 ...
# 535322    581199     84581        <NA>        -2 2011-12-07 18:26:00
# 535326    581203     23406        <NA>        15 2011-12-07 18:31:00
# 535332    581209     21620        <NA>         6 2011-12-07 18:35:00
# 536981    581234     72817        <NA>        27 2011-12-08 10:33:00
# 538554    581408     85175        <NA>        20 2011-12-08 14:06:00
#
#         UnitPrice  CustomerID         Country
# 622           0.0         NaN  United Kingdom
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  string
#  1   StockCode    541909 non-null  string
#  2   Description  540455 non-null  string
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  string
# dtypes: datetime64[ns](1), float64(2), int64(1), string(4)
# memory usage: 33.1 MB

# %% [markdown]
# #### DATA Cleaning

# %%
df1.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df1[df1.StockCode=="22139"].Description.mode()
# Out:
# 0    RETROSPOT TEA SET CERAMIC 11 PC
# Name: Description, dtype: string

# %%
most_freq= df1[["StockCode","Description"]].value_counts().reset_index()
most_freq
# Out:
#      StockCode                         Description  count
# 0       85123A  WHITE HANGING HEART T-LIGHT HOLDER   2302
# 1        22423            REGENCY CAKESTAND 3 TIER   2200
# 2       85099B             JUMBO BAG RED RETROSPOT   2159
# 3        47566                       PARTY BUNTING   1727
# 4        20725             LUNCH BAG RED RETROSPOT   1638
# ...        ...                                 ...    ...
# 4787     21491     SET OF THREE VINTAGE GIFT WRAPS      1
# 4788    84876D                             damaged      1
# 4789     20827                             damages      1
# 4790     20832                               check      1
# 4791     21578                                   ?      1
#
# [4792 rows x 3 columns]

# %%
most_freq[most_freq.StockCode=="85123A"]
# Out:
#      StockCode                         Description  count
# 0       85123A  WHITE HANGING HEART T-LIGHT HOLDER   2302
# 3320    85123A  CREAM HANGING HEART T-LIGHT HOLDER      9
# 4283    85123A                                   ?      1
# 4284    85123A         wrongly marked carton 22804      1

# %%
most_freq[most_freq.StockCode=="85123A"].head(1)
# Out:
#   StockCode                         Description  count
# 0    85123A  WHITE HANGING HEART T-LIGHT HOLDER   2302

# %%
most_freq = most_freq.groupby("StockCode").head(1)
most_freq
# Out:
#      StockCode                          Description  count
# 0       85123A   WHITE HANGING HEART T-LIGHT HOLDER   2302
# 1        22423             REGENCY CAKESTAND 3 TIER   2200
# 2       85099B              JUMBO BAG RED RETROSPOT   2159
# 3        47566                        PARTY BUNTING   1727
# 4        20725              LUNCH BAG RED RETROSPOT   1638
# ...        ...                                  ...    ...
# 4755     37503      TEA TIME CAKE STAND IN GIFT BOX      1
# 4773     37461                     FUNKY MONKEY MUG      1
# 4775     37474  SET/4 2 TONE EGG SHAPE MIXING BOWLS      1
# 4782     22145      CHRISTMAS CRAFT HEART STOCKING       1
# 4787     21491      SET OF THREE VINTAGE GIFT WRAPS      1
#
# [3958 rows x 3 columns]

# %%
most_freq.columns=["StockCode", "freq_description", "count"]
df2=df1.merge(most_freq,on="StockCode",how="left")
df2.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
#
#                       freq_description   count
# 0   WHITE HANGING HEART T-LIGHT HOLDER  2302.0
# 1                  WHITE METAL LANTERN   328.0
# ...

# %%
df2["Description"] = df2["freq_description"]
df2.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
#
#                       freq_description   count
# 0   WHITE HANGING HEART T-LIGHT HOLDER  2302.0
# 1                  WHITE METAL LANTERN   328.0
# ...

# %%
df2.isnull().sum()
# Out:
# InvoiceNo                0
# StockCode                0
# Description            112
# Quantity                 0
# InvoiceDate              0
# UnitPrice                0
# CustomerID          135080
# Country                  0
# freq_description       112
# count                  112
# dtype: int64

# %%
df2.dropna(subset=["Description"], inplace=True)

# %%
df2.isnull().sum()
# Out:
# InvoiceNo                0
# StockCode                0
# Description              0
# Quantity                 0
# InvoiceDate              0
# UnitPrice                0
# CustomerID          134968
# Country                  0
# freq_description         0
# count                    0
# dtype: int64

# %%
df2.drop(columns= ["freq_description", "count"], inplace=True)
df2.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
df2.describe()
# Out:
#             Quantity                    InvoiceDate      UnitPrice  \
# count  541797.000000                         541797  541797.000000
# mean        9.555919  2011-07-04 14:06:48.671255296       4.612067
# min    -80995.000000            2010-12-01 08:26:00  -11062.060000
# 25%         1.000000            2011-03-28 11:36:00       1.250000
# 50%         3.000000            2011-07-20 08:59:00       2.080000
# 75%        10.000000            2011-10-19 11:41:00       4.130000
# max     80995.000000            2011-12-09 12:50:00   38970.000000
# std       218.103428                            NaN      96.769831
#
#           CustomerID
# count  406829.000000
# mean    15287.690570
# min     12346.000000
# 25%     13953.000000
# 50%     15152.000000
# 75%     16791.000000
# max     18287.000000
# std      1713.600303

# %%
df2[df2.Quantity<0]
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                            Manual        -1
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df2[df2.UnitPrice<0]
# Out:
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 299983   A563186         B  Adjust bad debt         1 2011-08-12 14:51:00
# 299984   A563187         B  Adjust bad debt         1 2011-08-12 14:52:00
#
#         UnitPrice  CustomerID         Country
# 299983  -11062.06         NaN  United Kingdom
# 299984  -11062.06         NaN  United Kingdom

# %%
df3=df2[(df2.UnitPrice>0) & (df2.Quantity>0)]
df3.describe()
# Out:
#             Quantity                    InvoiceDate      UnitPrice  \
# count  530104.000000                         530104  530104.000000
# mean       10.542037  2011-07-04 20:16:05.225087744       3.907625
# min         1.000000            2010-12-01 08:26:00       0.001000
# 25%         1.000000            2011-03-28 12:22:00       1.250000
# 50%         3.000000            2011-07-20 12:58:00       2.080000
# 75%        10.000000            2011-10-19 12:39:00       4.130000
# max     80995.000000            2011-12-09 12:50:00   13541.330000
# std       155.524124                            NaN      35.915681
#
#           CustomerID
# count  397884.000000
# mean    15294.423453
# min     12346.000000
# 25%     13969.000000
# 50%     15159.000000
# 75%     16795.000000
# max     18287.000000
# std      1713.141560

# %%
# to remove outliers use quantile,IQR or 3-standard deviations methods
# 99% of records contain quantity 100 or less
df3.Quantity.quantile(0.99)
# Out:
# np.float64(100.0)

# %%
df3[df3.Quantity>1500]
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 4850      536809     84950       ASSORTED COLOUR T-LIGHT HOLDER      1824
# 4945      536830     84077    WORLD WAR 2 GLIDERS ASSTD DESIGNS      2880
# 25920     538420     17096    ASSORTED LAQUERED INCENSE HOLDERS      1728
# 32671     539101     22693   GROW A FLYTRAP OR SUNFLOWER IN TIN      2400
# 52709     540815    85123A   WHITE HANGING HEART T-LIGHT HOLDER      1930
# 52710     540815     21175          GIN + TONIC DIET METAL SIGN      2000
# 52711     540815     21108   FAIRY CAKE FLANNEL ASSORTED COLOUR      3114
# 61619     541431     23166       MEDIUM CERAMIC TOP STORAGE JAR     74215
# 80742     543057     84077    WORLD WAR 2 GLIDERS ASSTD DESIGNS      2592
# 87631     543669     22693   GROW A FLYTRAP OR SUNFLOWER IN TIN      2400
# 91772     544152     18007  ESSENTIAL BALM 3.5g TIN IN ENVELOPE      2400
# 97432     544612     22053                EMPIRE DESIGN ROSETTE      3906
# ...

# %% [markdown]
# ####Feature Engineering : Create New columns

# %%
df4= df3.copy()
df4['Total Price']=df4['Quantity']*df4['UnitPrice']
df4.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Total Price
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom        15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom        20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom        22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom        20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom        20.34

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 530104 entries, 0 to 541908
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    530104 non-null  string
#  1   StockCode    530104 non-null  string
#  2   Description  530104 non-null  string
#  3   Quantity     530104 non-null  int64
#  4   InvoiceDate  530104 non-null  datetime64[ns]
#  5   UnitPrice    530104 non-null  float64
#  6   CustomerID   397884 non-null  float64
#  7   Country      530104 non-null  string
#  8   Total Price  530104 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(1), string(4)
# memory usage: 40.4 MB

# %%
#extracting month from InvoiceDate column
df4['Month']=df4['InvoiceDate'].dt.month
df4.sample(3)
# Out:
#        InvoiceNo StockCode                        Description  Quantity  \
# 44437     540176     21242               RED RETROSPOT PLATE         96
# 459624    575875     23368  SET 12 COLOUR PENCILS DOLLY GIRL          1
# 237764    557885     21561    DINOSAUR LUNCH BOX WITH CUTLERY         6
#
#                InvoiceDate  UnitPrice  CustomerID         Country  \
# 44437  2011-01-05 12:40:00       1.45     17511.0  United Kingdom
# 459624 2011-11-11 13:06:00       1.25         NaN  United Kingdom
# 237764 2011-06-23 13:37:00       2.55     12465.0         Belgium
#
#         Total Price  Month
# 44437        139.20      1
# 459624         1.25     11
# 237764        15.30      6

# %% [markdown]
# ##Visualizaion and EDA

# %% [markdown]
# ####Plot monthly sales

# %%
monthly_sales = df4.groupby('Month')['Total Price'].sum().rename(("Total Price","Total Sales"),inplace=True)
monthly_sales
# Out:
# Month
# 1      691364.560
# 2      523631.890
# 3      717639.360
# 4      537808.621
# 5      770536.020
# 6      761739.900
# 7      719221.191
# 8      759138.380
# 9     1058590.172
# 10    1154979.300
# 11    1509496.330
# 12    1462538.820
# Name: (Total Price, Total Sales), dtype: float64

# %%
monthly_sales.plot(kind="bar", title="Monthly sales")
plt.xlabel("Month")
plt.ylabel("Total Sales")
plt.show()

# %%
monthly_sales.plot(kind="line", title="Monthly sales", marker="x")
plt.xlabel("Month")
plt.ylabel("Total Sales")
plt.grid()
plt.show()

# %% [markdown]
# ##Insights
# Total sales started rising up in August having a peek in peek . This is likely due to the holiday season in the end of the year

# %% [markdown]
# #### Top 5 countries by sales

# %%
# prompt: plot horizontal bar chart for top 5 countries by total sales

top_5_countries = df4.groupby('Country')['Total Price'].sum().sort_values(ascending=False).head(5)
top_5_countries
# Out:
# Country
# United Kingdom    9025222.084
# Netherlands        285446.340
# EIRE               283453.960
# Germany            228867.140
# France             209715.110
# Name: Total Price, dtype: float64

# %%
#horizontal bar
top_5_countries.plot(kind="barh", title="Top 5 countries by Monthly sales")
plt.xlabel("Total Price")
plt.ylabel("Country")
plt.grid(axis='x')
plt.show()

# %%
# prompt: plot same chart as above but this time use percentage contribution show % on the bar


# Calculate percentages
country_sales = df4.groupby('Country')['Total Price'].sum()
total_sales = country_sales.sum()
percentage_contribution = (country_sales / total_sales) * 100

# Create the bar plot
plt.figure(figsize=(8, 6))  # Adjust figure size for better readability
bars = plt.barh(country_sales.index, percentage_contribution, color='skyblue')
plt.xlabel("Percentage Contribution (%)")
plt.ylabel("Country")
plt.title("Countries by Sales Percentage Contribution")
plt.grid(axis='x')

# Add percentage labels to the bars
for bar, percentage in zip(bars, percentage_contribution):
    plt.text(bar.get_width() + 1, bar.get_y() + bar.get_height()/2, f'{percentage:.1f}%', va='center')


plt.show()

# %%
product_wise_sales = df4.groupby('StockCode')['Total Price'].sum()
top_5_products= product_wise_sales.sort_values(ascending=False).head(5)
top_5_products.plot(kind="barh",color='skyblue')
plt.title("Product-wise sales")
plt.xlabel('Total Sales')
plt.ylabel('product stock code')
plt.gca().invert_yaxis # to show the highest sales at the top
plt.show()

# %%
product_wise_sales.sum()
# Out:
# np.float64(10666684.544)

# %%
df4[df4.StockCode=="DOT"]
# Out:
#        InvoiceNo StockCode     Description  Quantity         InvoiceDate  \
# 1814      536544       DOT  DOTCOM POSTAGE         1 2010-12-01 14:32:00
# 3041      536592       DOT  DOTCOM POSTAGE         1 2010-12-01 17:06:00
# 5450      536862       DOT  DOTCOM POSTAGE         1 2010-12-03 11:13:00
# 5545      536864       DOT  DOTCOM POSTAGE         1 2010-12-03 11:27:00
# 5685      536865       DOT  DOTCOM POSTAGE         1 2010-12-03 11:28:00
# ...          ...       ...             ...       ...                 ...
# 536834    581219       DOT  DOTCOM POSTAGE         1 2011-12-08 09:28:00
# 537254    581238       DOT  DOTCOM POSTAGE         1 2011-12-08 10:53:00
# 539368    581439       DOT  DOTCOM POSTAGE         1 2011-12-08 16:30:00
# 540908    581492       DOT  DOTCOM POSTAGE         1 2011-12-09 10:03:00
# 541540    581498       DOT  DOTCOM POSTAGE         1 2011-12-09 10:26:00
#
#         UnitPrice  CustomerID         Country  Total Price  Month
# ...

# %%
for stock_code in top_5_products.index:
  description = df4[df4.StockCode==stock_code].Description.iloc[0]
  print(f"{stock_code} ==> {description}")
# Out:
# DOT ==> DOTCOM POSTAGE
# 22423 ==> REGENCY CAKESTAND 3 TIER
# 23843 ==> PAPER CRAFT , LITTLE BIRDIE
# 85123A ==> WHITE HANGING HEART T-LIGHT HOLDER
# 47566 ==> PARTY BUNTING

# %%
# prompt: plot same chart as above but use percentage this time


# Calculate percenta
total_sales = product_wise_sales.sum()
percentage= (top_5_products/total_sales)*100
plt.figure(figsize=(10, 6))
bars= plt.barh(top_5_products.index, percentage)
plt.xlabel("Percentage Contribution to total sales")
plt.ylabel("Product Stock Code")
plt.title("Top 5 products by percentage contribution to total sales")
plt.grid(axis='x')
 # Add percentage labels to the bars
for bar, percentage in zip(bars, percentage):
    plt.text(bar.get_width() + 1, bar.get_y() + bar.get_height()/2, f'{percentage:.1f}%', va='center')
plt.show()

# %% [markdown]
# ####RFM Analysis

# %%
df4["InvoiceDate"].max()#add one day
# Out:
# Timestamp('2011-12-09 12:50:00')

# %%
current_dt= df4['InvoiceDate'].max()+pd.Timedelta(days=1)
current_dt
# Out:
# Timestamp('2011-12-10 12:50:00')

# %%
rfm = df4.groupby("CustomerID").agg({"InvoiceDate":lambda x :(current_dt - x.max()).days,
                               "InvoiceNo": 'count', 'Total Price':'sum'})
rfm.columns = ['Recency', 'frequency', 'monetary']
rfm.head(5)
# Out:
#             Recency  frequency  monetary
# CustomerID
# 12346.0         326          1  77183.60
# 12347.0           2        182   4310.00
# 12348.0          75         31   1797.24
# 12349.0          19         73   1757.55
# 12350.0         310         17    334.40

# %%
df4[df4.CustomerID==12346]
# Out:
#       InvoiceNo StockCode                     Description  Quantity  \
# 61619    541431     23166  MEDIUM CERAMIC TOP STORAGE JAR     74215
#
#               InvoiceDate  UnitPrice  CustomerID         Country  Total Price  \
# 61619 2011-01-18 10:01:00       1.04     12346.0  United Kingdom      77183.6
#
#        Month
# 61619      1

# %%
df4[df4.CustomerID==12347]['Total Price'].sum()
# Out:
# np.float64(4310.000000000001)

# %%
#qcut function takes a column and cuts it into 4 quartiles
#Segment customers based on RFM
rfm['R_segment']= pd.qcut(rfm['Recency'],q=4,labels=[4,3,2,1])
rfm['F_segment']= pd.qcut(rfm['frequency'],q=4,labels=[1,2,3,4])
rfm['M_segment']= pd.qcut(rfm['monetary'],q=4,labels=[1,2,3,4])
rfm['RFM_score']=rfm[['R_segment','F_segment','M_segment']].sum(axis=1)

rfm
# Out:
#             Recency  frequency  monetary R_segment F_segment M_segment  \
# CustomerID
# 12346.0         326          1  77183.60         1         1         4
# 12347.0           2        182   4310.00         4         4         4
# 12348.0          75         31   1797.24         2         2         4
# 12349.0          19         73   1757.55         3         3         4
# 12350.0         310         17    334.40         1         1         2
# ...             ...        ...       ...       ...       ...       ...
# 18280.0         278         10    180.60         1         1         1
# 18281.0         181          7     80.82         1         1         1
# 18282.0           8         12    178.05         4         1         1
# 18283.0           4        756   2094.88         4         4         4
# 18287.0          43         70   1837.28         3         3         4
#
#             RFM_score
# CustomerID
# 12346.0             6
# 12347.0            12
# ...

# %%
rfm.sort_values('RFM_score', ascending=False)
# Out:
#             Recency  frequency  monetary R_segment F_segment M_segment  \
# CustomerID
# 18283.0           4        756   2094.88         4         4         4
# 18245.0           7        175   2567.06         4         4         4
# 18241.0          10        104   2073.09         4         4         4
# 18229.0          12        164   7276.90         4         4         4
# 18225.0           3        271   5509.12         4         4         4
# ...             ...        ...       ...       ...       ...       ...
# 16471.0         275         13    223.95         1         1         1
# 18224.0         264         10    158.95         1         1         1
# 18220.0         227          2    305.28         1         1         1
# 13011.0         372          3     50.55         1         1         1
# 13008.0         323         14    229.47         1         1         1
#
#             RFM_score
# CustomerID
# 18283.0            12
# 18245.0            12
# ...

# %% [markdown]
# ##Customer Churn Analysis

# %%
customer_last_purchase = df4.groupby('CustomerID')['InvoiceDate'].max()
customer_last_purchase.head()
# Out:
# CustomerID
# 12346.0   2011-01-18 10:01:00
# 12347.0   2011-12-07 15:52:00
# 12348.0   2011-09-25 13:13:00
# 12349.0   2011-11-21 09:51:00
# 12350.0   2011-02-02 16:01:00
# Name: InvoiceDate, dtype: datetime64[ns]

# %%
customer_last_purchase = (current_dt - customer_last_purchase).dt.days
customer_last_purchase.head()
# Out:
# CustomerID
# 12346.0    326
# 12347.0      2
# 12348.0     75
# 12349.0     19
# 12350.0    310
# Name: InvoiceDate, dtype: int64

# %%
churn_threshold= 90
churned_customers = customer_last_purchase[customer_last_purchase > churn_threshold]
churned_customers.head()
# Out:
# CustomerID
# 12346.0    326
# 12350.0    310
# 12353.0    204
# 12354.0    232
# 12355.0    214
# Name: InvoiceDate, dtype: int64

# %%
print("Number of churned customers:", len(churned_customers))
# Out:
# Number of churned customers: 1449

# %%
plt.figure(figsize=(10, 6))
plt.hist(customer_last_purchase, bins=50, color='red', alpha=0.7)
plt.axvline(churn_threshold, color='black', linestyle='dashed', linewidth=2)
plt.title('Customer churn Distribution')
plt.xlabel('Days since last purchase')
plt.ylabel('Number of Customers')
plt.show()

# %% [markdown]
# #Fireducks

# %%
import time
stime= time.time()
df1=pd.concat([df1]*60)
df1.shape
# Out:
# (32514540, 8)

# %% [markdown]
# Timestamp

# %%
print(f"[{pd.__name__}]total time taken: {time.time()-stime} sec")
# Out:
# [pandas]total time taken: 196.3719506263733 sec

# %% [markdown]
# ###Importing Fireducks

# %%
# !pip install fireducks
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 46.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.1/42.1 MB 20.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 18.1.0
#     Uninstalling pyarrow-18.1.0:
#       Successfully uninstalled pyarrow-18.1.0
# ...
